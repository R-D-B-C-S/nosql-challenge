# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %%
pprint(establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64615cec082e95aedb827361'),
#  'geocode': {'latitude': Decimal128('51.083812'),
#              'longitude': Decimal128('1.195625')},
# ...

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query ={'scores.Hygiene':20}

# Use count_documents to display the number of documents in the result
print(establishments.count_documents(query))
# Display the first document in the results using pprint
pprint(establishments.find(query)[0])
# Out:
# 41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64615ced082e95aedb828e92'),
#  'geocode': {'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
# ...

# %%
# Convert the result to a Pandas DataFrame
Twenty_Hygiene=pd.DataFrame(establishments.find(query))
Twenty_Hygiene.info()
Twenty_Hygiene.head(10)
# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   _id                         41 non-null     object
#  1   FHRSID                      41 non-null     int64
#  2   ChangesByServerID           41 non-null     int64
#  3   LocalAuthorityBusinessID    41 non-null     object
#  4   BusinessName                41 non-null     object
#  5   BusinessType                41 non-null     object
#  6   BusinessTypeID              41 non-null     int64
#  7   AddressLine1                41 non-null     object
#  8   AddressLine2                41 non-null     object
#  9   AddressLine3                41 non-null     object
#  10  AddressLine4                41 non-null     object
#  11  PostCode                    41 non-null     object
#  12  Phone                       41 non-null     object
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query ={'LocalAuthorityName':{'$regex':'London'},
    'RatingValue':{'$gte':4}}

# Use count_documents to display the number of documents in the result
establishments.count_documents(query)
# Display the first document in the results using pprint
pprint(establishments.find(query)[0])
# Out:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64615ced082e95aedb82a8ad'),
#  'geocode': {'latitude': Decimal128('51.369321'),
#              'longitude': Decimal128('0.508551')},
# ...

# %%
# Convert the result to a Pandas DataFrame
London_Ratings =pd.DataFrame(establishments.find(query))
# Display the number of rows in the DataFrame
London_Ratings.info()
# Display the first 10 rows of the DataFrame
London_Ratings.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   _id                         33 non-null     object
#  1   FHRSID                      33 non-null     int64
#  2   ChangesByServerID           33 non-null     int64
#  3   LocalAuthorityBusinessID    33 non-null     object
#  4   BusinessName                33 non-null     object
#  5   BusinessType                33 non-null     object
#  6   BusinessTypeID              33 non-null     int64
#  7   AddressLine1                33 non-null     object
#  8   AddressLine2                33 non-null     object
#  9   AddressLine3                33 non-null     object
#  10  AddressLine4                33 non-null     object
#  11  PostCode                    33 non-null     object
#  12  Phone                       33 non-null     object
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01

latitude = 51.49
longitude = 0.0838
lat_upper_bound=latitude + degree_search
lat_lower_bound=longitude - degree_search
lat_query = {'$gte':lat_lower_bound,'$lte':lat_upper_bound}


long_upper_bound=longitude+degree_search
long_lower_bound=longitude-degree_search
long_query= {'$gte':long_lower_bound,'$lte':long_upper_bound}

query = {'geocode.latitude':lat_query,
        'geocode.longitude':long_query,
        'RatingValue':5}
#sort =  {('Hygiene',-1)}

results =list(establishments.find(query)[0:5].sort('Hygiene',-1))
#results =list(establishments.find(query))[0:5]
#.limit(5)

# Print the results
pprint(results)
# Out:
# [{'AddressLine1': '80-88 Claremont Road',
#   'AddressLine2': 'Seaford',
#   'AddressLine3': 'East Sussex',
#   'AddressLine4': '',
#   'BusinessName': 'Clifden House Dementia Care Centre',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4621.062630784395,
#   'FHRSID': 174047,
#   'LocalAuthorityBusinessID': 'PI/000027871',
#   'LocalAuthorityCode': '105',
#   'LocalAuthorityEmailAddress': 'ehealth.ldc@lewes-eastbourne.gov.uk',
#   'LocalAuthorityName': 'Lewes',
#   'LocalAuthorityWebSite': 'http://www.lewes-eastbourne.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'BN25 2QD',
#   'RatingDate': '2021-08-12T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64615ced082e95aedb8298c2'),
#   'geocode': {'latitude': Decimal128('50.776112'),
#               'longitude': Decimal128('0.089886')},
# ...

# %%
query = {'BusinessName':"Penang Flavours"}
pprint(establishments.find(query)[0])
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64616241f79056d07bfae1c3'),
#  'geocode': {'latitude': Decimal128('51.49014200'),
#              'longitude': Decimal128('0.08384000')},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %%
# Convert result to Pandas DataFrame
Proximate_To_Pengang=pd.DataFrame(results)
Proximate_To_Pengang.head()
# Out:
#                         _id  FHRSID  ChangesByServerID  \
# 0  64615ced082e95aedb8298c2  174047                  0
# 1  64615ced082e95aedb8298c8  173610                  0
# 2  64615ced082e95aedb82986d  637054                  0
# 3  64615ced082e95aedb82986c  174020                  0
# 4  64615ced082e95aedb829870  664257                  0
#
#   LocalAuthorityBusinessID                        BusinessName  \
# 0             PI/000027871  Clifden House Dementia Care Centre
# 1             PI/000026322                Beachlands Care Home
# 2             PI/000061384                Costcutter Claremont
# 3             PI/000027807                   Angies Newsagents
# 4             PI/000027811                      R & B Fish Bar
#
#              BusinessType  BusinessTypeID          AddressLine1 AddressLine2  \
# 0         Caring Premises               5  80-88 Claremont Road      Seaford
# 1         Caring Premises               5         Marine Parade      Seaford
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0

match_query = {'$match': {'scores.Hygiene': 0}}

group_query = {'$group': {'_id': "$LocalAuthorityName", 'count': { '$sum': 1 }}}

# Create a dictionary that will allow the pipeline to sort by count in descending order
sort_values = {'$sort': { 'count': -1 }}

# Put the pipeline together
pipeline = [match_query, group_query, sort_values]


# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# Print the number of documents in the result

# Print the first 10 results

# %%
results = list(establishments.aggregate(pipeline))
pprint(results[0:10])
# Out:
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
unique_values = establishments.distinct("LocalAuthorityName")

# Print the unique values
for value in unique_values:
    print(value)
# Out:
# Aberdeenshire
# Arun
# Ashford
# Babergh
# Barking and Dagenham
# Basildon
# Bexley
# Braintree
# Brentwood
# Bromley
# Broxbourne
# Canterbury City
# Castle Point
# Chelmsford
# City of London Corporation
# Colchester
# Dartford
# Dorset
# East Hertfordshire
# East Renfrewshire
# East Suffolk
# Eastbourne
# Epping Forest
# Folkestone and Hythe
# Gravesham
# Greenwich
# Hackney
# Harlow
# Hastings
# Havering
# Ipswich
# Kensington and Chelsea
# Knowsley
# Lambeth
# Lewes
# Lewisham
# Maidstone
# Maldon
# Medway
# Mid Sussex
# Newham
# North Hertfordshire
# North Norfolk
# Orkney Islands
# Pendle
# Reading
# Redbridge
# Rochford
# Rother
# Rushmoor
# Salford
# Sevenoaks
# Slough
# South Cambridgeshire
# Southend-On-Sea
# Spelthorne
# Stratford-on-Avon
# Sunderland
# Swale
# Tandridge
# Tendring
# Thanet
# Thurrock
# Tonbridge and Malling
# Tower Hamlets
# Tunbridge Wells
# Uttlesford
# Waltham Forest
# Wealden
# West Suffolk
# York

# %%
# Convert the result to a Pandas DataFrame
Zero_Hygiene= pd.DataFrame(results)
# Display the number of rows in the DataFrame
Zero_Hygiene.info()
# Display the first 10 rows of the DataFrame
Zero_Hygiene.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   _id     55 non-null     object
#  1   count   55 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1008.0+ bytes
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
